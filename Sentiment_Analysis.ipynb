# %%
# !pip install textblob
# Sentiment Analysis of Tweets using Python
# Out:
# ...
#    ---------------------------------------- 0.0/624.3 kB ? eta -:--:--
#    --------------------------------------- 624.3/624.3 kB 11.7 MB/s eta 0:00:00
# ...
#                                                Tweet Sentiment
# 0                I love the new phone, it's amazing!  Positive
# 1     I hate the traffic today. Terrible experience.  Negative
# 2  The weather is okay, not bad but not great eit...  Positive
# 3                  What a fantastic game last night!   Neutral
# 4   I am very sad and disappointed with the service.  Negative

# %%
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt

# Sample tweets (you can expand this list or fetch real tweets later)
tweets = [
    "I love the new phone, it's amazing!",
    "I hate the traffic today. Terrible experience.",
    "The weather is okay, not bad but not great either.",
    "What a fantastic game last night!",
    "I am very sad and disappointed with the service."
]

# Create a DataFrame
df = pd.DataFrame(tweets, columns=['Tweet'])

# Function to get sentiment
def get_sentiment(text):
    analysis = TextBlob(text)
    if analysis.sentiment.polarity > 0:
        return 'Positive'
    elif analysis.sentiment.polarity < 0:
        return 'Negative'
    else:
        return 'Neutral'

# Apply sentiment analysis
df['Sentiment'] = df['Tweet'].apply(get_sentiment)

# Print results
print(df)

# Plot sentiment counts
df['Sentiment'].value_counts().plot(kind='bar', color=['green', 'red', 'blue'])
plt.title('Sentiment Analysis of Sample Tweets')
plt.xlabel('Sentiment')
plt.ylabel('Count')
plt.show()
# Out:
#                                                Tweet Sentiment
# 0                I love the new phone, it's amazing!  Positive
# 1     I hate the traffic today. Terrible experience.  Negative
# 2  The weather is okay, not bad but not great eit...  Positive
# 3                  What a fantastic game last night!   Neutral
# 4   I am very sad and disappointed with the service.  Negative
